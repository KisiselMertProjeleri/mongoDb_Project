# %%
SEED_DATA = [
  {
    'genre': 'Fantasy',
    'title': 'The Lord of the Rings: The Fellowship of the Ring',
    'author': 'J.R.R. Tolkien',
    'year': 1954,
  },
  {
    'genre': 'Science Fiction',
    'title': 'Dune',
    'author': 'Frank Herbert',
    'year': 1965,
  },
  {
    'genre': 'Dystopian',
    'title': '1984',
    'author': 'George Orwell',
    'year': 1949,
  }
]

# %% [markdown]
# # Uygulamalar

# %% [markdown]
# # Soru 1

# %% [markdown]
# Mongo Db'de yeni bir veri tabani ve collection olusturup buna baglanin

# %%
from pymongo import MongoClient

client = MongoClient('mongodb+srv://bruceleonymann:wZa4LVqaFAhbgzIz@deneme1.19txh.mongodb.net/')

# %%
veri_tabani = client['entellektüeller']
tablo = veri_tabani['yazarlar']
tablo
# Out:
# Collection(Database(MongoClient(host=['deneme1-shard-00-00.19txh.mongodb.net:27017', 'deneme1-shard-00-02.19txh.mongodb.net:27017', 'deneme1-shard-00-01.19txh.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-k4xoqb-shard-0', tls=True), 'entellektüeller'), 'yazarlar')

# %%
import random
new_data = []

for i in range(100):
    veriler =  random.choice(SEED_DATA)
    yeni_veri = {
        'genre': veriler['genre'],
        'title': veriler['title'],
        'author': veriler['author'],
        'year': veriler['year']
    }
    new_data.append(yeni_veri)
for veri in new_data:
    print(veri)

# %%
tablo.insert_many(new_data)
# Out:
# InsertManyResult([ObjectId('675da05c2b39d13d617513c8'), ObjectId('675da05c2b39d13d617513c9'), ObjectId('675da05c2b39d13d617513ca'), ObjectId('675da05c2b39d13d617513cb'), ObjectId('675da05c2b39d13d617513cc'), ObjectId('675da05c2b39d13d617513cd'), ObjectId('675da05c2b39d13d617513ce'), ObjectId('675da05c2b39d13d617513cf'), ObjectId('675da05c2b39d13d617513d0'), ObjectId('675da05c2b39d13d617513d1'), ObjectId('675da05c2b39d13d617513d2'), ObjectId('675da05c2b39d13d617513d3'), ObjectId('675da05c2b39d13d617513d4'), ObjectId('675da05c2b39d13d617513d5'), ObjectId('675da05c2b39d13d617513d6'), ObjectId('675da05c2b39d13d617513d7'), ObjectId('675da05c2b39d13d617513d8'), ObjectId('675da05c2b39d13d617513d9'), ObjectId('675da05c2b39d13d617513da'), ObjectId('675da05c2b39d13d617513db'), ObjectId('675da05c2b39d13d617513dc'), ObjectId('675da05c2b39d13d617513dd'), ObjectId('675da05c2b39d13d617513de'), ObjectId('675da05c2b39d13d617513df'), ObjectId('675da05c2b39d13d617513e0'), ObjectId('675da05c2b39d13d6175
# ...

# %% [markdown]
# # Soru 2

# %% [markdown]
# Kendiniz yukaridakine benzer ama sadece 1 döküman olusturup bu dökümani mongodb'ye aktariniz. Bunun icin insert_many() methodunu kullanmayiniz.

# %%
veri = {
    "genre":"korku",
    'title':'ölümcül köy',
    'author':'Mert',
    'year':'1987'
}
tablo.insert_one(veri)
# Out:
# InsertOneResult(ObjectId('675d94302b39d13d617513c7'), acknowledged=True)

# %%
veriler = tablo.find({'author':'Mert'})
for veri in veriler:
    print(veri)
# Out:
# {'_id': ObjectId('675d94302b39d13d617513c7'), 'genre': 'korku', 'title': 'ölümcül köy', 'author': 'Mert', 'year': '1987'}

# %% [markdown]
# # Soru 3

# %% [markdown]
# author fieldi George orwell olan documentin genre fieldini Scince_Fiction olarak güncelleyini ve yazdiriniz.

# %%
sorgu = {'author':'George Orwell'}
tablo.update_many(sorgu,{'$set':{'genre':'Science Fiction'}})
# Out:
# UpdateResult({'n': 31, 'electionId': ObjectId('7fffffff000000000000000a'), 'opTime': {'ts': Timestamp(1734186592, 31), 't': 10}, 'nModified': 31, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1734186592, 31), 'signature': {'hash': b'-\x04\xaaCU\x1d0q\x06\xbc\x8alo87\xdc\x12\xb1\xa1k', 'keyId': 7418578331844476932}}, 'operationTime': Timestamp(1734186592, 31), 'updatedExisting': True}, acknowledged=True)

# %%
veri = tablo.find(sorgu)
for data in veri:
    print(data)
# Out:
# {'_id': ObjectId('675d920b2b39d13d61751366'), 'genre': 'Science Fiction', 'title': '1984', 'author': 'George Orwell', 'year': 1949}
# {'_id': ObjectId('675d920b2b39d13d61751367'), 'genre': 'Science Fiction', 'title': '1984', 'author': 'George Orwell', 'year': 1949}
# {'_id': ObjectId('675d920b2b39d13d6175136a'), 'genre': 'Science Fiction', 'title': '1984', 'author': 'George Orwell', 'year': 1949}
# {'_id': ObjectId('675d920b2b39d13d6175136f'), 'genre': 'Science Fiction', 'title': '1984', 'author': 'George Orwell', 'year': 1949}
# {'_id': ObjectId('675d920b2b39d13d61751370'), 'genre': 'Science Fiction', 'title': '1984', 'author': 'George Orwell', 'year': 1949}
# {'_id': ObjectId('675d920b2b39d13d61751375'), 'genre': 'Science Fiction', 'title': '1984', 'author': 'George Orwell', 'year': 1949}
# {'_id': ObjectId('675d920b2b39d13d6175137c'), 'genre': 'Science Fiction', 'title': '1984', 'author': 'George Orwell', 'year': 1949}
# ...

# %% [markdown]
# # Soru 4

# %% [markdown]
# Kitabin Basim yilinin 1950'den fazla olanlari yazdirin. For döngüsü ile anlasilabilir bir format olusturun. Bunun icin '$gte'methodunu kullanin.

# %%
veriler = tablo.find({'year':{'$gte':1950}})
for veri in veriler:
    print(f"""
        --------------------------------
        Kitap Türü: {veri['genre']}

        Kitap Adi: {veri['title']}

        Kitap Yazari: {veri['author']}

        Kitap Basim Yili: {veri['year']}
        --------------------------------
""")
# Out:
#         --------------------------------
#         Kitap Türü: Fantasy
#
#         Kitap Adi: The Lord of the Rings: The Fellowship of the Ring
#
#         Kitap Yazari: J.R.R. Tolkien
#
#         Kitap Basim Yili: 1954
#         --------------------------------
#
#
#         --------------------------------
#         Kitap Türü: Science Fiction
#
#         Kitap Adi: Dune
#
#         Kitap Yazari: Frank Herbert
#
#         Kitap Basim Yili: 1965
#         --------------------------------
#
#
#         --------------------------------
#         Kitap Türü: Science Fiction
#
#         Kitap Adi: Dune
#
#         Kitap Yazari: Frank Herbert
#
#         Kitap Basim Yili: 1965
#         --------------------------------
#
#
#         --------------------------------
#         Kitap Türü: Science Fiction
#
#         Kitap Adi: Dune
#
#         Kitap Yazari: Frank Herbert
#
#         Kitap Basim Yili: 1965
#         --------------------------------
#
#
# ...
